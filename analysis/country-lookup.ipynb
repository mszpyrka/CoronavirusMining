# %%
import numpy as np
import pandas as pd
import pycountry as pc
import ast
import re

# %%
translation_file = './countries-translation/global_names.csv'
translation_df = pd.read_csv(translation_file, keep_default_na=False, na_values=[''])
translation_df.head()
# Out:
#    Unnamed: 0 continent english_name  \
# 0           0    europe      albania
# 1           1    europe      andorra
# 2           2    europe      austria
# 3           3    europe   azerbaijan
# 4           4    europe      belarus
#
#                                         native_names alpha_2
# 0  ['shqipëria', 'republika e shqipërisë', 'repub...      AL
# 1  ['andorra', "principat d'andorra", 'principali...      AD
# 2  ['österreich', 'republik österreich', 'republi...      AT
# 3  ['azərbaycan', 'азәрбајҹан', 'آذربايجان', 'azə...      AZ
# 4  ['biełaruśбеларусь', 'respublika biełaruś', 'р...      BY

# %%
translation_df[translation_df['alpha_2'].isnull().values == True]
# Out:
#     Unnamed: 0 continent          english_name  \
# 17          17    europe                alsace
# 19          19    europe  languedoc-roussillon
#
#                                          native_names alpha_2
# 17             ['alsace', 'elsàss', 'elsass / elsaß']     NaN
# 19  ['languedoc-roussillon', 'lengadòc-rosselhon',...     NaN

# %%
ast.literal_eval(translation_df.iloc[0]['native_names'])
# Out:
# ['shqipëria', 'republika e shqipërisë', 'republic of albania']

# %%
class CountryLookup:
    def __init__(self, translation_file):
        translation_df = pd.read_csv(translation_file, keep_default_na=False, na_values=[''])
        clean_df = translation_df[translation_df['alpha_2'].isnull().values == False]
        translation_dict = {}
        
        for _, row in clean_df.iterrows():
            alpha_2 = row['alpha_2']
            translation_dict[row['english_name']] = alpha_2
            
            native_names = ast.literal_eval(row['native_names'])
            for native in native_names:
                translation_dict[native] = alpha_2
                
            pc_record = pc.countries.lookup(alpha_2)
#             translation_dict[alpha_2.lower()] = alpha_2
            translation_dict[pc_record.name.lower()] = alpha_2
    
            try:
                translation_dict[pc_record.official_name.lower()] = alpha_2
            except AttributeError:
                continue
            
        self.translation_dict = translation_dict
        
    def __getitem__(self, key):
        key = key.lower()
        key_parts = re.split(r'[?.,-]', key)
        key_parts = [k for k in key_parts if len(k) > 0]
        for k in key_parts:
            k = ' '.join(k.split())
            lookup = self.translation_dict.get(k)
            if lookup is not None:
                return lookup
            
        return None

# %%
lookup = CountryLookup(translation_file)
lookup.translation_dict
# Out:
# {'albania': 'AL',
#  'shqipëria': 'AL',
#  'republika e shqipërisë': 'AL',
#  'republic of albania': 'AL',
#  'andorra': 'AD',
#  "principat d'andorra": 'AD',
#  'principality of andorra': 'AD',
#  'austria': 'AT',
#  'österreich': 'AT',
#  'republik österreich': 'AT',
#  'republic of austria': 'AT',
#  'azerbaijan': 'AZ',
#  'azərbaycan': 'AZ',
#  'азәрбајҹан': 'AZ',
#  'آذربايجان': 'AZ',
#  'azərbaycan respublikası': 'AZ',
#  'азәрбајҹан республикаси': 'AZ',
#  'azerbaijani republic': 'AZ',
#  'republic of azerbaijan': 'AZ',
#  'belarus': 'BY',
#  'biełaruśбеларусь': 'BY',
#  'respublika biełaruś': 'BY',
#  'рэспублика беларусь': 'BY',
#  'republic of belarus': 'BY',
#  'belgium': 'BE',
#  'belgië': 'BE',
#  'belgique': 'BE',
#  'belgien': 'BE',
#  'koninkrijk belgië': 'BE',
#  'royaume de belgique': 'BE',
#  'königreich belgien': 'BE',
#  'kingdom of belgium': 'BE',
#  'bosnia and herzegovina': 'BA',
#  'bosna i hercegovina': 'BA',
#  'босна и херцеговина': 'BA',
#  'republic of bosnia and herzegovina': 'BA',
#  'bulgaria': 'BG',
#  'българия': 'BG',
#  'република българия': 'BG',
#  'republic of bulgaria': 'BG',
#  'croatia': 'HR',
#  'hrvatska': 'HR',
#  'republika hrvatska': 'HR',
#  'republic of croatia': 'HR',
#  'cyprus': 'CY',
#  'κύπρος': 'CY',
#  'κυπριακή δημοκρατία': 'CY',
#  'kıbrıs': 'CY',
#  'kıbrıs cumhuriyeti': 'CY',
#  'republic of cyprus': 'CY',
#  'czech republic': 'CZ',
#  'česko': 'CZ',
#  'česká republika': 'CZ',
#  'czechia': 'CZ',
#  'denmark': 'DK',
#  'danmark': 'DK',
#  'kongeriget danmark': 'DK',
#  'kingdom of denmark': 'DK',
#  'estonia': 'EE',
#  'eesti': 'EE',
#  'eesti vabariik': 'EE',
#  'republic of estonia': 'EE',
#  'faroe islands': 'FO',
#  'føroyar': 'FO',
#  'færøerne': 'FO',
#  'finland': 'FI',
#  'suomi': 'FI',
#  'suomen tasavalta': 'FI',
#  'republiken finland': 'FI',
#  'republic of finland': 'FI',
#  'france': 'FR',
#  'république française': 'FR',
#  'frantzia': 'FR',
#  'frantziako errepublika': 'FR',
#  "bro-c'hall": 'FR',
#  "republik c'hall": 'FR',
#  'frança': 'FR',
#  'la república francesa': 'FR',
#  'francia': 'FR',
#  'republica francese': 'FR',
#  'la republica francesa': 'FR',
#  'french republic': 'FR',
#  'brittany': 'FR',
#  'bretagne': 'FR',
#  'breizh': 'FR',
#  'bertaèyn': 'FR',
#  'aquitaine': 'FR',
#  'aquitània': 'FR',
#  'akitania': 'FR',
#  'provence': 'FR',
#  'provença / prouvènço': 'FR',
#  'germany': 'DE',
#  'deutschland': 'DE',
#  'bundesrepublik deutschland': 'DE',
#  'federal republic of germany': 'DE',
#  'greece': 'GR',
#  'ελλάδα': 'GR',
#  'έλλας': 'GR',
#  'ελληνική δημοκρατία': 'GR',
#  'hellenic republic;': 'GR',
#  'republic of greece': 'GR',
#  'hellenic republic': 'GR',
#  'guernsey': 'GG',
#  'dgèrnésy': 'GG',
#  'bailiwick of guernesey': 'GG',
#  'bailliage de guernesey': 'GG',
#  'hungary': 'HU',
#  'magyarország': 'HU',
#  'iceland': 'IS',
#  'ísland': 'IS',
#  'lýðveldið ísland': 'IS',
#  'republic of iceland': 'IS',
#  'ireland': 'IE',
#  'republic of ireland': 'IE',
#  'éire': 'IE',
#  'poblacht na héireann': 'IE',
#  'isle of man': 'IM',
#  'mannin': 'IM',
#  'ellan vannin': 'IM',
#  'italy': 'IT',
#  'italia': 'IT',
#  'repubblica italiana': 'IT',
#  'italian republic': 'IT',
#  'jersey': 'JE',
#  'bailiwick of jersey': 'JE',
#  'jèrri': 'JE',
#  'bailliage de jersey': 'JE',
#  'latvia': 'LV',
#  'latvija': 'LV',
#  'latvijas republika': 'LV',
#  'republic of latvia': 'LV',
#  'liechtenstein': 'LI',
#  'fürstentum liechtenstein': 'LI',
#  'principality of liechtenstein': 'LI',
#  'lithuania': 'LT',
#  'lietuva': 'LT',
#  'lietuvos respublika': 'LT',
#  'republic of lithuania': 'LT',
#  'luxembourg': 'LU',
#  'lëtzebuerg': 'LU',
#  'grousherzogdem lëtzebuerg': 'LU',
#  'grand-duché de luxembourg': 'LU',
#  'luxemburg': 'LU',
#  'großherzogtum luxemburg': 'LU',
#  'grand duchy of luxembourg': 'LU',
#  'macedonia': 'MK',
#  'македонија': 'MK',
#  'република': 'RS',
#  'the republic of macedonia': 'MK',
#  'поранешна југословенска република македонија': 'MK',
#  'former yugoslav republic of macedonia': 'MK',
#  'north macedonia': 'MK',
#  'republic of north macedonia': 'MK',
#  'malta': 'MT',
#  "repubblika ta' malta": 'MT',
#  'republic of malta': 'MT',
#  'moldova': 'MD',
#  'молдова': 'MD',
#  'republica moldovaрепублика': 'MD',
#  'republic of moldova': 'MD',
#  'moldova, republic of': 'MD',
#  'monaco': 'MC',
#  'principauté de monaco': 'MC',
#  'principality of monaco': 'MC',
#  'montenegro': 'ME',
#  'црна гора': 'ME',
#  'netherlands, holland': 'NL',
#  'nederland': 'NL',
#  'koninkrijk der nederlanden': 'NL',
#  'nederlân': 'NL',
#  'keninkryk fan de nederlannen': 'NL',
#  'kingdom of the netherlands': 'NL',
#  'netherlands': 'NL',
#  'norway': 'NO',
#  'norge': 'NO',
#  'kongeriket norge': 'NO',
#  'noreg': 'NO',
#  'kongeriket noreg': 'NO',
#  'kingdom of norway': 'NO',
#  'poland': 'PL',
#  'polska': 'PL',
#  'rzeczpospolita polska': 'PL',
#  'republic of poland': 'PL',
#  'portugal': 'PT',
#  'república portuguesa': 'PT',
#  'portuguese republic': 'PT',
#  'romania': 'RO',
#  'românia': 'RO',
#  'russia': 'RU',
#  'россия': 'RU',
#  'российская': 'RU',
#  'федерация': 'RU',
#  'russian federation': 'RU',
#  'san marino': 'SM',
#  'serenissima repubblica di san marino': 'SM',
#  'most serene republic of san marino': 'SM',
#  'republic of san marino': 'SM',
#  'serbia': 'RS',
#  'србија': 'RS',
#  'republic of serbia': 'RS',
#  'slovakia': 'SK',
#  'slovensko': 'SK',
#  'slovenska republika': 'SK',
#  'slovak republic': 'SK',
#  'slovenia': 'SI',
#  'slovenija': 'SI',
#  'republika slovenija': 'SI',
#  'republic of slovenia': 'SI',
#  'spain': 'ES',
#  'españa': 'ES',
#  'reino de españa': 'ES',
#  'espanya': 'ES',
#  "reino d'espanya": 'ES',
#  "reinu d'españa": 'ES',
#  'espainia': 'ES',
#  'espainiako erresuma': 'ES',
#  "regne d'espanya": 'ES',
#  'espanha': 'ES',
#  "reiaume d'espanha": 'ES',
#  'kingdom of spain': 'ES',
#  'sweden': 'SE',
#  'sverige': 'SE',
#  'konungariket sverige': 'SE',
#  'kingdom of sweden': 'SE',
#  'switzerland': 'CH',
#  'confoederatio helvetica': 'CH',
#  'helvetic confederation': 'CH',
#  'die schweiz': 'CH',
#  'schweizerische eidgenossenschaft': 'CH',
#  'suisse': 'CH',
#  'confederation suisse': 'CH',
#  'svizzera': 'CH',
#  'confederazione svizzera': 'CH',
#  'svizra': 'CH',
#  'confederaziun svizra': 'CH',
#  'swiss confederation': 'CH',
#  'turkey': 'TR',
#  'türkiye': 'TR',
#  'türkiye cumhuriyeti': 'TR',
#  'republic of turkey': 'TR',
#  'united kingdom': 'GB',
#  'united kingdom of great britain and northern ireland': 'GB',
#  'teyrnas unedig': 'GB',
#  'teyrnas unedig prydain fawr a gogledd iwerddon': 'GB',
#  'an rywvaneth unys': 'GB',
#  'an rywvaneth unys a vreten veur hag iwerdhon gledh': 'GB',
#  'an rìoghachd aonaichte': 'GB',
#  'rìoghachd aonaichte bhreatainn agus éirinn a tuath': 'GB',
#  'ríocht aontaithe': 'GB',
#  'ríocht aontaithe na breataine móire agus thuaisceart éireann': 'GB',
#  'unitit kinrick': 'GB',
#  'unitit kinrick o great breetain an northren ireland': 'GB',
#  'england': 'GB',
#  'sasainn': 'GB',
#  'ingland': 'GB',
#  'lloegr': 'GB',
#  'inglond': 'GB',
#  'sasana': 'GB',
#  'scotland': 'GB',
#  'alba': 'GB',
#  'rìoghachd na h-alba': 'GB',
#  'kinrick o scotland': 'GB',
#  'kingdom of scotland': 'GB',
#  'yr alban': 'GB',
#  'teyrnas yr alban': 'GB',
#  'alban': 'GB',
#  'ruwvaneth alban': 'GB',
#  'albain': 'GB',
#  'ríocht na halban': 'GB',
#  'wales': 'GB',
#  'cymru': 'GB',
#  'kembra': 'GB',
#  "a' chuimrigh": 'GB',
#  'an bhreatain bheag': 'GB',
#  'cornwall': 'GB',
#  'kernow': 'GB',
#  'dugeth kernow': 'GB',
#  'duchy of cornwall': 'GB',
#  'cernyw': 'GB',
#  'dugiaeth cernyw': 'GB',
#  "a' chòrn": 'GB',
#  'diùcachd na còirne': 'GB',
#  'corn na breataine': 'GB',
#  'diúcacht chorn na breataine': 'GB',
#  'northern ireland': 'GB',
#  'tuaisceart éireann': 'GB',
#  'norlin airlann': 'GB',
#  'éirinn a tuath': 'GB',
#  'gogledd iwerddon': 'GB',
#  'ukraine': 'UA',
#  'україна - ukrainian': 'UA',
#  'украина - russian': 'UA',
#  'vatican city': 'VA',
#  'vaticanum': 'VA',
#  'status civitatis vaticanae': 'VA',
#  'state of vatican city': 'VA',
#  'holy see (vatican city state)': 'VA',
#  'argentina': 'AR',
#  'república argentina': 'AR',
#  'argentine republic': 'AR',
#  'bolivia': 'BO',
#  'república de bolivia': 'BO',
#  'republic of bolivia': 'BO',
#  'bolivia, plurinational state of': 'BO',
#  'plurinational state of bolivia': 'BO',
#  'brazil': 'BR',
#  'brasil': 'BR',
#  'república federativa do brasil': 'BR',
#  'federal republic of brazil': 'BR',
#  'federative republic of brazil': 'BR',
#  'chile': 'CL',
#  'república de chile': 'CL',
#  'republic of chile': 'CL',
#  'colombia': 'CO',
#  'república de colombia': 'CO',
#  'republic of colombia': 'CO',
#  'ecuador': 'EC',
#  'república del ecuador': 'EC',
#  'republic of ecuador': 'EC',
#  'french guiana': 'GF',
#  'guyane': 'GF',
#  'department of guiana': 'GF',
#  'guyana': 'GY',
#  'co-operative republic of guyana': 'GY',
#  'republic of guyana': 'GY',
#  'paraguay': 'PY',
#  'paraguái': 'PY',
#  'república del paraguay': 'PY',
#  'tetã paraguáipe': 'PY',
#  'republic of paraguay': 'PY',
#  'peru': 'PE',
#  'perú': 'PE',
#  'república del perú': 'PE',
#  'republic of peru': 'PE',
#  'suriname': 'SR',
#  'republiek suriname': 'SR',
#  'republic of suriname': 'SR',
#  'uruguay': 'UY',
#  'república oriental del uruguay': 'UY',
#  'oriental republic of uruguay': 'UY',
#  'eastern republic of uruguay': 'UY',
#  'venezuela': 'VE',
#  'república bolivariana de venezuela': 'VE',
#  'bolivarian republic of venezuela': 'VE',
#  'venezuela, bolivarian republic of': 'VE',
#  'canada': 'CA',
#  'ᑲᓇᑕ - inuktitut': 'CA',
#  'greenland': 'GL',
#  'grønland': 'GL',
#  'kalaallit nunaat': 'GL',
#  'self-governing territory of greenland': 'GL',
#  'mexico': 'MX',
#  'méxico': 'MX',
#  'anahuac': 'MX',
#  'mexihco': 'MX',
#  'estados unidos mexicanos': 'MX',
#  'united mexican states': 'MX',
#  'usa': 'US',
#  'ꭰꮊꭲ': 'US',
#  'united states of america': 'US',
#  'wááshindoon bikéyah ałhidadiidzooígíí': 'US',
#  'ꭴᏼꮲꭲ-ꭰꮊꮅꭶ ꮩᏹꮧꮲ ꭶꮪꮂ': 'US',
#  '- cherokee': 'US',
#  'ᑭᐦᒋ ᒨᐦᑯᒫᓇᐢᑭᕀ': 'US',
#  '- cree': 'US',
#  "'amelika-hui-pu-'ia": 'US',
#  'estados unidos de américa': 'US',
#  "états-unis d'amérique": 'US',
#  'פֿאַראײניקטע': 'US',
#  'שטאַטן פֿון': 'US',
#  'אַמעריקע': 'US',
#  '- yiddish': 'US',
#  'united states': 'US',
#  'belize': 'BZ',
#  'costa rica': 'CR',
#  'república de costa rica': 'CR',
#  'republic of costa rica': 'CR',
#  'el salvador': 'SV',
#  'república de el salvador': 'SV',
#  'republic of el salvador': 'SV',
#  'guatemala': 'GT',
#  'república de guatemala': 'GT',
#  'republic of guatemala': 'GT',
#  'honduras': 'HN',
#  'república de honduras': 'HN',
#  'republic of honduras': 'HN',
#  'nicaragua': 'NI',
#  'república de nicaragua': 'NI',
#  'republic of nicaragua': 'NI',
#  'panama': 'PA',
#  'panamá': 'PA',
#  'república de panamá': 'PA',
#  'republic of panama': 'PA',
#  'antigua and barbuda': 'AG',
#  'the bahamas': 'BS',
#  'commonwealth of the bahamas': 'BS',
#  'bahamas': 'BS',
#  'barbados': 'BB',
#  'dominica': 'DM',
#  'commonwealth of dominica': 'DM',
#  'dominican republic': 'DO',
#  'república dominicana': 'DO',
#  'cuba': 'CU',
#  'república de cuba': 'CU',
#  'republic of cuba': 'CU',
#  'grenada': 'GD',
#  'state of grenada': 'GD',
#  'haiti': 'HT',
#  'haïti': 'HT',
#  'ayiti': 'HT',
#  "république d'haïti": 'HT',
#  'repiblik dayiti': 'HT',
#  'republic of haiti': 'HT',
#  'jamaica': 'JM',
#  'saint kitts and nevis': 'KN',
#  'federation of saint kitts and nevis': 'KN',
#  'saint lucia': 'LC',
#  'saint vincent and the grenadines': 'VC',
#  'trinidad and tobago': 'TT',
#  'republic of trinidad and tobago': 'TT',
#  'australia': 'AU',
#  'commonwealth of australia': 'AU',
#  'fiji': 'FJ',
#  'viti': 'FJ',
#  'matanitu tu-vaka-i-koya ko viti': 'FJ',
#  'republic of the fiji islands': 'FJ',
#  'republic of fiji': 'FJ',
#  'kiribati': 'KI',
#  'ribaberikin kiribati': 'KI',
#  'republic of kiribati': 'KI',
#  'marshall islands': 'MH',
#  'aelōn̄ in m̧ajeļ': 'MH',
#  'republic of the marshall islands': 'MH',
#  'aolepān aorōkin m̧ajeļ': 'MH',
#  'micronesia': 'FM',
#  'federated states of micronesia': 'FM',
#  'micronesia, federated states of': 'FM',
#  'nauru': 'NR',
#  'naoero': 'NR',
#  'repubrikin naoero': 'NR',
#  'republic of nauru': 'NR',
#  'new zealand': 'NZ',
#  'aotearoa': 'NZ',
#  'land of the long white cloud': 'NZ',
#  'palau': 'PW',
#  'belau': 'PW',
#  "belu'u era belau": 'PW',
#  'republic of palau': 'PW',
#  'papua new guinea': 'PG',
#  'papua niugini': 'PG',
#  'independent state of papua new guinea': 'PG',
#  'samoa': 'WS',
#  'independent state of samoa': 'WS',
#  "malo sa'oloto tuto'atasi o samoa": 'WS',
#  'solomon islands': 'SB',
#  'tonga': 'TO',
#  "pule'anga fakatu'i 'o tonga": 'TO',
#  'kingdom of tonga': 'TO',
#  'tuvalu': 'TV',
#  'vanuatu': 'VU',
#  'ripablik blong vanuatu': 'VU',
#  'republic of vanuatu': 'VU',
#  'république du vanuatu': 'VU',
#  'afghanistan': 'AF',
#  'افغانستان': 'AF',
#  '- pashto': 'AF',
#  '- dari': 'AF',
#  'د افغانستان اسلامی جمهوريت': 'AF',
#  'جمهوری اسلامی افغانستان': 'AF',
#  'islamic republic of afghanistan': 'AF',
#  'armenia': 'AM',
#  'հայաստան': 'AM',
#  'հայաստանի հանրապետություն': 'AM',
#  'republic of armenia': 'AM',
#  'bahrain': 'BH',
#  'البحرين': 'BH',
#  'مملكة البحرين': 'BH',
#  'the kingdom of bahrain': 'BH',
#  'kingdom of bahrain': 'BH',
#  'bangladesh': 'BD',
#  'বাংলাদেশ': 'BD',
#  'গণপ্রজাতন্ত্রী বাংলাদেশ': 'BD',
#  "people's republic of bangladesh": 'BD',
#  'bhutan': 'BT',
#  'འབྲུག་ཡུལ།': 'BT',
#  'kingdom of bhutan': 'BT',
#  'brunei darussalam': 'BN',
#  'بروني دارالسلام': 'BN',
#  'نڬارا بروني دارالسلام': 'BN',
#  'negara brunei darussalam': 'BN',
#  'state of brunei darussalam': 'BN',
#  'burma / myanmar': 'MM',
#  'မြန်မာ': 'MM',
#  'ဗမာ': 'MM',
#  'ပြည်ထောင်စု သမ္မတ မြန်မာနိုင်ငံတော်\u200c': 'MM',
#  'republic of the union of myanmarr': 'MM',
#  'myanmar': 'MM',
#  'republic of myanmar': 'MM',
#  'cambodia': 'KH',
#  'កម្ពុជា': 'KH',
#  'ព្រះរាជាណាចក្រកម្ពុជា': 'KH',
#  'kingdom of cambodia': 'KH',
#  'china': 'CN',
#  '中国': 'CN',
#  '中华人民共和国': 'CN',
#  "people's republic of china": 'CN',
#  'hong kong': 'HK',
#  '香港': 'HK',
#  '香港特別行政區': 'HK',
#  '(hèunggóng dahkbihit hàhngjingkèui': 'HK',
#  'xiānggǎng tèbié xíngzhèngqū)': 'HK',
#  'hong kong special administrative region': 'HK',
#  'hong kong special administrative region of china': 'HK',
#  'macau': 'MO',
#  '澳門': 'MO',
#  '(ngoumún,': 'MO',
#  'àomén)': 'MO',
#  '澳門特別行政區': 'MO',
#  '(ngoumún dahkbihit hàhngjingkèui': 'MO',
#  'àomén tèbié xíngzhèngqū)': 'MO',
#  'região administrativa especial de macau': 'MO',
#  'macau special administrative region': 'MO',
#  'macao': 'MO',
#  'macao special administrative region of china': 'MO',
#  'east timor': 'TL',
#  "timór lorosa'e": 'TL',
#  'timor-leste': 'TL',
#  "repúblika demokrátika timór lorosa'e": 'TL',
#  'república democrática de timor-leste': 'TL',
#  'democratic republic of timor-leste': 'TL',
#  'georgia': 'GE',
#  'საქართველო': 'GE',
#  'საქართველოს რესპუბლიკა': 'GE',
#  'republic of georgia': 'GE',
#  'india': 'IN',
#  'ভাৰত': 'IN',
#  'ভাৰত গণৰাজ্য': 'IN',
#  'republic of india': 'IN',
#  'ভারত': 'IN',
#  'ভারতীয় প্রজাতন্ত্র': 'IN',
#  'ભારત': 'IN',
#  'ભારતીય ગણરાજ્ય': 'IN',
#  'भारत': 'IN',
#  'भारत गणराज्य': 'IN',
#  'ಭಾರತ': 'IN',
#  'ಭಾರತ ಗಣರಾಜ್ಯ': 'IN',
#  'ഭാരതം': 'IN',
#  'ഭാരത ഗണരാജ്യം': 'IN',
#  'भारत प्रजासत्ताक': 'IN',
#  'ଭାରତ': 'IN',
#  'ଭାରତ ଗଣରାଜ୍ୟ': 'IN',
#  'ਭਾਰਤ': 'IN',
#  'ਭਾਰਤ ਗਣਰਾਜ': 'IN',
#  'भारतम्': 'IN',
#  'भारतमहाराज्यम्': 'IN',
#  'ڀارت': 'IN',
#  'இந்தியா': 'IN',
#  'இந்தியக் குடியரசு': 'IN',
#  'భారత': 'IN',
#  'భారత గణ రాజ్యము': 'IN',
#  'indonesia': 'ID',
#  'republik indonesia': 'ID',
#  'republic of indonesia': 'ID',
#  'iran': 'IR',
#  'ايران': 'IR',
#  'جمهورى اسلامى ايران': 'IR',
#  'islamic republic of iran': 'IR',
#  'iran, islamic republic of': 'IR',
#  'iraq': 'IQ',
#  'العراق': 'IQ',
#  'جمهورية العراق': 'IQ',
#  'republic of iraq': 'IQ',
#  'israel': 'IL',
#  'ישׂראל': 'IL',
#  'إسرائيل': 'IL',
#  'מדינת ישראל': 'IL',
#  'دولة إسرائيل': 'IL',
#  'state of israel': 'IL',
#  'japan': 'JP',
#  '日本': 'JP',
#  '日本国': 'JP',
#  'jordan': 'JO',
#  'الأردن': 'JO',
#  'المملكة الأردنية الهاشمية': 'JO',
#  'hashemite kingdom of jordan': 'JO',
#  'kazakhstan': 'KZ',
#  'қазақстан': 'KZ',
#  'қазақстан республикасы': 'KZ',
#  'republic of kazakhstan': 'KZ',
#  'korea': 'KP',
#  '조선': 'KP',
#  '조선 민주주의 인민 공화국': 'KP',
#  "democratic people's republic of korea": 'KP',
#  "korea, democratic people's republic of": 'KP',
#  '한국': 'KP',
#  '대한민국': 'KP',
#  'republic of korea': 'KP',
#  'kuwait': 'KW',
#  'الكويت': 'KW',
#  'دولة الكويت': 'KW',
#  'state of kuwait': 'KW',
#  'kyrgyzstan': 'KG',
#  'кыргызстан': 'KG',
#  'кыргызстан республикасы': 'KG',
#  'kyrgyz republic': 'KG',
#  'laos': 'LA',
#  'ລາວ': 'LA',
#  'ສາທາລະນະລັດ ປະຊາທິປະໄຕ ປະຊາຊົນ ລາວ': 'LA',
#  "lao people's democratic republic": 'LA',
#  'lebannon': 'LB',
#  'لبنان': 'LB',
#  'الجمهوريّة اللبنانية': 'LB',
#  'lebanese republic': 'LB',
#  'lebanon': 'LB',
#  'maldives': 'MV',
#  'ދިވެހި': 'MV',
#  'ދިވެހި ޖުމްހުރިޔަ': 'MV',
#  'maldive republic': 'MV',
#  'republic of maldives': 'MV',
#  'malaysia': 'MY',
#  'مليسيا': 'MY',
#  'persekutuan tanah malaysia': 'MY',
#  'ڤرسكوتوان تانه مليسيا': 'MY',
#  'federation of malaysia': 'MY',
#  'mongolia': 'MN',
#  'монгол улс': 'MN',
#  'ᠮᠤᠩᠭᠤᠯ ᠤᠯᠤᠰ': 'MN',
#  'nepal': 'NP',
#  'नेपाल': 'NP',
#  'सङ्घीय लोकतान्त्रिक गणतन्त्र नेपा': 'NP',
#  'federal democratic republic of nepal': 'NP',
#  'oman': 'OM',
#  'عمان': 'OM',
#  'سلطنة عمان': 'OM',
#  'sultanate of oman': 'OM',
#  'pakistan': 'PK',
#  'پاکستان': 'PK',
#  'سلامی جمهرويت پاکستان': 'PK',
#  'islamic republic of pakistan': 'PK',
#  'palestine': 'PS',
#  'فلسطين': 'PS',
#  'دولة فلسطين': 'PS',
#  'state of palestine': 'PS',
#  'palestine, state of': 'PS',
#  'the state of palestine': 'PS',
#  'philippines': 'PH',
#  'pilipinas': 'PH',
#  'republika ng pilipinas': 'PH',
#  'republic of the philippines': 'PH',
#  'qatar': 'QA',
#  'قطر': 'QA',
#  'دولة قطر': 'QA',
#  'state of qatar': 'QA',
#  'republic of china, taipei': 'CN',
#  '臺灣': 'CN',
#  '中華民國': 'CN',
#  'republic of china': 'CN',
#  'российская федерация': 'RU',
#  'saudi arabia': 'SA',
#  'السعودية': 'SA',
#  'المملكة العربية السعودية': 'SA',
#  'kingdom of saudi arabia': 'SA',
#  'singapore': 'SG',
#  '新加坡': 'SG',
#  '新加坡共和国': 'SG',
#  'republic of singapore': 'SG',
#  'singapura': 'SG',
#  'republik singapura': 'SG',
#  'சிங்கப்பூர்': 'SG',
#  'சிங்கப்பூர் குடியரசு': 'SG',
#  'sri lanka': 'LK',
#  'ශ්රී ලංකා': 'LK',
#  'ශ්රී ලංකා ප්රජාතාන්ත්රික සමාජවාදී ජනරජය': 'LK',
#  'democratic socialist republic of sri lanka': 'LK',
#  'இலங்கை': 'LK',
#  'இலங்கை ஜனநாயக சோஷலிசக் குடியரசு': 'LK',
#  'syria': 'SY',
#  'سورية': 'SY',
#  'الجمهورية العربية السورية': 'SY',
#  'al-ǧumhūrīyâ al-ʿarabīyâ as-sūrīyâ': 'SY',
#  'syrian arab republic': 'SY',
#  'tajikistan': 'TJ',
#  'тоҷикистон': 'TJ',
#  'ҷумҳурии тоҷикистон': 'TJ',
#  'republic of tajikistan': 'TJ',
#  'thailand': 'TH',
#  'ประเทศไทย': 'TH',
#  'ราชอาณาจักรไทย': 'TH',
#  'kingdom of thailand': 'TH',
#  "timor lorosa'e": 'TL',
#  "repúblika demokrátika timor lorosa'e": 'TL',
#  'turkmenistan': 'TM',
#  'туркменистан': 'TM',
#  'uae': 'AE',
#  'الامارات': 'AE',
#  'دولة الإمارات العربية المتحدة': 'AE',
#  'united arab emirates': 'AE',
#  'uzbekistan': 'UZ',
#  'ўзбекистон': 'UZ',
#  "o'zbekiston": 'UZ',
#  'ўзбекистон республикасй': 'UZ',
#  "o'zbekiston respublikasi": 'UZ',
#  'republic of uzbekistan': 'UZ',
#  'vietnam': 'VN',
#  'việt nam': 'VN',
#  'cộng hoà xã hội chủ nghĩa việt nam': 'VN',
#  'socialist republic of vietnam': 'VN',
#  'viet nam': 'VN',
#  'socialist republic of viet nam': 'VN',
#  'yemen': 'YE',
#  'اليمن': 'YE',
#  'الجمهوريّة اليمنية': 'YE',
#  'republic of yemen': 'YE',
#  'algeria': 'DZ',
#  'الجزائر': 'DZ',
#  'الجمهوريّة': 'EH',
#  'الجزائريّة': 'DZ',
#  'الديمقراطيّة': 'EH',
#  'الشعبيّة': 'LY',
#  "(al-jumhūrīyâtt al-jazā'irīyât ad-dīmuqrāṭīyâ": 'DZ',
#  'aš-šaʿbīyâ)': 'DZ',
#  'democratic and popular republic of algeria': 'DZ',
#  "people's democratic republic of algeria": 'DZ',
#  'angola': 'AO',
#  'república de angola': 'AO',
#  'republic of angola': 'AO',
#  'benin': 'BJ',
#  'bénin': 'BJ',
#  'république du bénin': 'BJ',
#  'republic of benin': 'BJ',
#  'botswana': 'BW',
#  'lefatshe la botswana': 'BW',
#  'republic of botswana': 'BW',
#  'burkina faso': 'BF',
#  'burundi': 'BI',
#  'uburundi': 'BI',
#  "republika y'uburundi": 'BI',
#  'république du burundi': 'BI',
#  'republic of burundi': 'BI',
#  'cameroon': 'CM',
#  'cameroun': 'CM',
#  'république du cameroun': 'CM',
#  'republic of cameroon': 'CM',
#  'chad': 'TD',
#  'tchad': 'TD',
#  'تشاد': 'TD',
#  'république du tchad': 'TD',
#  'جمهوريّة': 'SD',
#  'republic of chad': 'TD',
#  'cape verde': 'CV',
#  'cabo verde': 'CV',
#  'república de cabo verde': 'CV',
#  'republic of cape verde': 'CV',
#  'republic of cabo verde': 'CV',
#  'central african republic': 'CF',
#  'centrafrique': 'CF',
#  'bê-afrîka': 'CF',
#  'république centrafricaine': 'CF',
#  'ködrö tî bê-afrîka': 'CF',
#  'comoros': 'KM',
#  'comores': 'KM',
#  'komori': 'KM',
#  'القمر': 'KM',
#  'union des comores': 'KM',
#  'udzima wa komori': 'KM',
#  'اتحاد القمر': 'KM',
#  'union of the comoros': 'KM',
#  'congo': 'CG',
#  'république démocratique du congo': 'CG',
#  'democratic republic of the congo': 'CG',
#  'republic of the congo': 'CG',
#  'république du congo': 'CG',
#  "côte d'ivoire": 'CI',
#  "république de côte d'ivoire": 'CI',
#  "republic of côte d'ivoire": 'CI',
#  'djibouti': 'DJ',
#  'جيبوتي': 'DJ',
#  'république de djibouti': 'DJ',
#  'republic of djibouti': 'DJ',
#  'egypt': 'EG',
#  'مصر': 'EG',
#  'مصر العربيّة': 'EG',
#  'arabic republic of egypt': 'EG',
#  'arab republic of egypt': 'EG',
#  'equatorial guinea': 'GQ',
#  'guinea ecuatorial, guinée équatoriale': 'GQ',
#  'república de guinea ecuatorial': 'GQ',
#  'république de guinée équatoriale': 'GQ',
#  'republic of equatorial guinea': 'GQ',
#  'eritrea': 'ER',
#  'ኤርትራ': 'ER',
#  'إريتريا': 'ER',
#  'ሃግሬ ኤርትራ': 'ER',
#  'دولة إريتريا': 'ER',
#  'state of eritrea': 'ER',
#  'the state of eritrea': 'ER',
#  'ethiopia': 'ET',
#  'ኢትዮጵያ': 'ET',
#  'የኢትዮጵያ ፌዴራላዊ ዲሞክራሲያዊ': 'ET',
#  'ሪፐብሊ': 'ET',
#  'federal democratic republic of ethiopia': 'ET',
#  'gabon': 'GA',
#  'le gabon': 'GA',
#  'république gabonaise': 'GA',
#  'gabonese republic': 'GA',
#  'the gambia': 'GM',
#  'republic of the gambia': 'GM',
#  'gambia': 'GM',
#  'ghana': 'GH',
#  'republic of ghana': 'GH',
#  'guinea': 'GN',
#  'guinée': 'GN',
#  'république de guinée': 'GN',
#  'republic of guinea': 'GN',
#  'guinea-bissau': 'GW',
#  'guiné-bissau': 'GW',
#  'república da guiné-bissau': 'GW',
#  'republic of guinea-bissau': 'GW',
#  'kenya': 'KE',
#  'republic of kenya': 'KE',
#  'jamhuri ya kenya': 'KE',
#  'libya': 'LY',
#  'ليبيا': 'LY',
#  'الجماهيريّة': 'LY',
#  'العربيّة': 'EH',
#  'الليبيّة': 'LY',
#  'الاشتراكيّة': 'LY',
#  'العظمى': 'LY',
#  '(al-jamāhīrīyâ al-ʿarabīyâ al-lībīyâ': 'LY',
#  'aš-šaʿbīyâ al-ištirākīyâ)': 'LY',
#  "socialist people's libyan arab jamahiriya": 'LY',
#  'lesotho': 'LS',
#  'kingdom of lesotho': 'LS',
#  'mmuso wa lesotho': 'LS',
#  'liberia': 'LR',
#  'republic of liberia': 'LR',
#  'madagascar': 'MG',
#  'madagasikara, madagascar': 'MG',
#  "repoblikan'i madagasikara": 'MG',
#  'république de madagascar': 'MG',
#  'republic of madagascar': 'MG',
#  'malawi': 'MW',
#  'malaŵi': 'MW',
#  'republic of malawi': 'MW',
#  'mfuko la malaŵi': 'MW',
#  'mali': 'ML',
#  'république du mali': 'ML',
#  'republic of mali': 'ML',
#  'mauritania': 'MR',
#  'موريتانيا': 'MR',
#  'الإسلاميّة': 'MR',
#  'الموريتانيّة': 'MR',
#  'islamic republic of mauritania': 'MR',
#  'mauritius': 'MU',
#  'maurice': 'MU',
#  'republic of mauritius': 'MU',
#  'république de maurice': 'MU',
#  'morocco': 'MA',
#  'المغرب': 'MA',
#  'المملكة المغربيّة': 'MA',
#  'kingdom of morocco': 'MA',
#  'mozambique': 'MZ',
#  'moçambique': 'MZ',
#  'república de moçambique': 'MZ',
#  'republic of mozambique': 'MZ',
#  'namibia': 'NA',
#  'republic of namibia': 'NA',
#  'niger': 'NG',
#  'république du niger': 'NG',
#  'republic of niger': 'NG',
#  'nigeria': 'NG',
#  'federal republic of nigeria': 'NG',
#  'rwanda': 'RW',
#  "repubulika y'u rwanda": 'RW',
#  'république rwandaise': 'RW',
#  'republic of rwanda': 'RW',
#  'rwandese republic': 'RW',
#  'sao tome and principe': 'ST',
#  'são tomé e príncipe': 'ST',
#  'república democrática de são tomé e príncipe': 'ST',
#  'democratic republic of sao tome and principe': 'ST',
#  'senegal': 'SN',
#  'sénégal': 'SN',
#  'sounougal': 'SN',
#  'république du sénégal': 'SN',
#  'republic of senegal': 'SN',
#  'seychelles': 'SC',
#  'sesel': 'SC',
#  'repiblik sesel': 'SC',
#  'republic of seychelles': 'SC',
#  'république des seychelles': 'SC',
#  'sierra leone': 'SL',
#  'republic of sierra leone': 'SL',
#  'somalia': 'SO',
#  'soomaaliya': 'SO',
#  'jamhuuriyad-da dimoqradddiya soomaaliya': 'SO',
#  'republic of somalia': 'SO',
#  'federal republic of somalia': 'SO',
#  'south africa': 'ZA',
#  'republiek van suid-afrika': 'ZA',
#  'republic of south africa': 'ZA',
#  'rephaboliki ya afrika-borwa': 'ZA',
#  'iriphabliki yesewula afrika': 'ZA',
#  'rephaboliki ya afrika borwa': 'ZA',
#  'iriphabhulikhi yeningizimu afrika': 'ZA',
#  'riphabliki ra afrika dzonga': 'ZA',
#  'rephaboliki ya aforika borwa': 'ZA',
#  'riphabuḽiki ya afurika tshipembe': 'ZA',
#  'iriphabliki yasemzantsi afrika': 'ZA',
#  'iriphabliki yaseningizimu afrika': 'ZA',
#  'south sudan': 'SS',
#  'federal democratic republic of south sudan': 'SS',
#  'republic of south sudan': 'SS',
#  'sudan': 'SD',
#  'السودان': 'SD',
#  'republic of sudan': 'SD',
#  'republic of the sudan': 'SD',
#  'swaziland': 'SZ',
#  'eswatini': 'SZ',
#  'kangwane': 'SZ',
#  'umbuso weswatini': 'SZ',
#  'umbuso wakangwane': 'SZ',
#  'kingdom of swaziland': 'SZ',
#  'kingdom of eswatini': 'SZ',
#  'tanzania': 'TZ',
#  'jamhuri ya muungano wa tanzania': 'TZ',
#  'united republic of tanzania': 'TZ',
#  'tanzania, united republic of': 'TZ',
#  'togo': 'TG',
#  'république togolaise': 'TG',
#  'togolese republic': 'TG',
#  'tunisia': 'TN',
#  'تونس': 'TN',
#  'التونسيّة': 'TN',
#  'tunisian republic': 'TN',
#  'republic of tunisia': 'TN',
#  'uganda': 'UG',
#  'jamhuri ya uganda': 'UG',
#  'republic of uganda': 'UG',
#  'western sahara': 'EH',
#  'الصحراء': 'EH',
#  'العربيّة الصحراويّة': 'EH',
#  '(al-jumhūrīyâtu al-ʿarabīyâtu aṣ-ṣaḥrāwīyâtu': 'EH',
#  'ad-dīmuqrāṭīyâ)': 'EH',
#  'democratic sahrawi arab republic': 'EH',
#  'zambia': 'ZM',
#  'republic of zambia': 'ZM',
#  'zimbabwe': 'ZW',
#  'republic of zimbabwe': 'ZW'}

# %%
lookup['pakistan']
# Out:
# 'PK'

# %%
samples = ['Chatburn, England. ', ' ✈', 'Namibia, Windhoek', 'England',
       'Jacksonville, FL', 'Destroying autotune rap music',
       'Philadelphia, PA', 'These are personal comments.',
       'm ( a r t ) a', 'Straight outta Comte ', 'Ile-de-France, France',
       'Pie Barm', 'Baltimore, Maryland', 'SW Michigan',
       'Ikorudu, Nigeria', 'In the Eye of the Storm',
       'Pietermaritzburg, South Africa', 'Lehigh Valley PA',
       'Los Angeles, CA', 'Mansehra/Islamabad, Pakistan', 'Germany',
       'vmin’s pockets', 'Uk', 'Udupi | Mumbai | Dubai | ', 'Brussels',
       'Shenandoah Valley, Virginia', 'Australia',
       'Perth, Western Australia', 'New Jersey', 'L.A. - MANILA',
       'Tennessee', 'London', 'Gwangju, Korea', 'United States',
       'England, United Kingdom', 'New Delhi, India', 'London, England',
       'Cramlington, England', 'Karachi, Pakistan', 'London, UK']

# %%
for s in samples:
    print(s, lookup[s])
# Out:
# Chatburn, England.  GB
#  ✈ None
# Namibia, Windhoek NA
# England GB
# Jacksonville, FL None
# Destroying autotune rap music None
# Philadelphia, PA None
# These are personal comments. None
# m ( a r t ) a None
# Straight outta Comte  None
# Ile-de-France, France FR
# Pie Barm None
# Baltimore, Maryland None
# SW Michigan None
# Ikorudu, Nigeria NG
# In the Eye of the Storm None
# Pietermaritzburg, South Africa ZA
# Lehigh Valley PA None
# Los Angeles, CA None
# Mansehra/Islamabad, Pakistan PK
# Germany DE
# vmin’s pockets None
# Uk None
# Udupi | Mumbai | Dubai |  None
# Brussels None
# Shenandoah Valley, Virginia None
# Australia AU
# Perth, Western Australia None
# New Jersey None
# L.A. - MANILA None
# Tennessee None
# London None
# Gwangju, Korea KP
# United States US
# England, United Kingdom GB
# New Delhi, India IN
# London, England GB
# Cramlington, England GB
# Karachi, Pakistan PK
# London, UK None
